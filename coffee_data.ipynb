# %%
import pandas as pd
import numpy as np
import matplotlib as plt
coffee = pd.read_csv('data/data.csv')
coffee_reviews = pd.read_csv('data/data_with_review_count.csv')

# %%
coffee.describe()
# Out:
#             rating  price_level          lat          lon
# count  1241.000000  1667.000000  2601.000000  2601.000000
# mean      3.970588     1.479304    40.732453   -73.967123
# std       0.418327     0.566171     0.060525     0.038578
# min       1.700000     1.000000    40.575314   -74.039719
# 25%       3.700000     1.000000    40.703332   -73.993221
# 50%       4.000000     1.000000    40.737151   -73.978139
# 75%       4.300000     2.000000    40.763809   -73.949356
# max       4.900000     4.000000    40.887188   -73.851745
#
# [8 rows x 4 columns]

# %%
coffee_reviews
# Out:
#     rating                                    name  \
# 0      3.6                            Tatiana Cafe
# 1      NaN                          Dunkin' Donuts
# 2      NaN                  Trigo Cafe Corporation
# 3      3.7                         Footprints Cafe
# 4      NaN                            Third Season
# 5      NaN                               inLifeNYC
# 6      3.9                         Ocean View Cafe
# 7      NaN                           La Petit Cafe
# 8      4.2                               Starbucks
# 9      3.9                            Kashkar Cafe
# 10     3.9                             Anyway Cafe
# 11     NaN                               Cafeteria
# 12     NaN                          Dunkin' Donuts
# 13     3.9                            Cafe Glechik
# 14     NaN                              Cafe Paris
# 15     NaN                         Cafe Dolce Vita
# 16     NaN                        Panini Tozt Cafe
# ...

# %%
# Returns whether or not a point is in a polygon
def point_in_poly(x,y,poly):

    n = len(poly)
    inside = False

    p1x,p1y = poly[0]
    for i in range(n+1):
        p2x,p2y = poly[i % n]
        if y > min(p1y,p2y):
            if y <= max(p1y,p2y):
                if x <= max(p1x,p2x):
                    if p1y != p2y:
                        xints = (y-p1y)*(p2x-p1x)/(p2y-p1y)+p1x
                    if p1x == p2x or x <= xints:
                        inside = not inside
        p1x,p1y = p2x,p2y

    return inside

# %%
coffee_scores = [3.92424242424,3.8,4.1,4.09166666667,4.10555555556,0,4.15,4.2,4.26666666667,4.12608695652,4.2,0,4.08,4.02903225806,3.7375,3.98,4.15454545455,4.05,4.0,3.53333333333,4.08,3.53333333333,3.85,4.4,3.86666666667,3.8,3.93333333333,4.2,4.10625,3.975,3.7,3.9,3.955,0,4.08333333333,4.2125,3.4,3.8875,4.09677419355,3.92205882353,3.91428571429,3.91428571429,3.91428571429,3.91428571429,3.72,3.6,3.91538461538,4.04545454545,4.04230769231,3.99347826087,4.05094339623,3.91707317073,4.08444444444,4.03962264151,3.8724137931,3.72857142857,3.86382978723,4.05714285714,3.85769230769,3.9675,3.75333333333,3.82380952381,3.84782608696,3.82,3.91875,3.93448275862,4.14166666667,3.8875,4.05555555556,3.85,4.21333333333,3.93888888889,0,0,3.8,0,3.95,4.25,0,4.05,3.84285714286,3.98333333333,4.02,4.02,0,3.92424242424,3.92424242424,3.92424242424,3.92424242424,3.92424242424,3.92424242424,3.92424242424,3.92424242424,3.92424242424,3.92424242424,3.92424242424,3.4]

cs_series = pd.Series(coffee_scores)

def remove_values_from_list(the_list, val):
    return [value for value in the_list if value != val]

cs_series_no_zeros = pd.Series(remove_values_from_list(coffee_scores,0))

his = np.histogram(cs_series_no_zeros,bins=7)
len(coffee_scores)
# Out:
# 97

# %%
cs_series_no_zeros.describe()
# Out:
# count    89.000000
# mean      3.949566
# std       0.174335
# min       3.400000
# 25%       3.872414
# 50%       3.924242
# 75%       4.055556
# max       4.400000
# dtype: float64

# %%
import matplotlib.pyplot as plt
# plt.figure()
# cs_series.hist(color='k', alpha=0.5, bins=50)
# plt.show()

font = {'size'   : 14}

plt.rc('font', **font)

plt.figure()
cs_series_no_zeros.hist(color='g', alpha=0.5, bins=50, range=(1,5))
plt.xlabel('Mean score by postcode', fontsize=20)
plt.ylabel('Count', fontsize= 18)
plt.xlim((1,5))
plt.show()

# %%
individual_scores = [3.6, 3.7, 3.9, 4.2, 3.9, 3.9, 3.9, 4, 4, 3.9, 3.4, 3, 4.2, 3.9, 4.3, 3.9, 4.2, 4, 4, 4.3, 4.6, 4, 3.9, 1.7, 4.2, 4.5, 3.5, 3.8, 4.4, 4.4, 3.8, 4.7, 4.2, 3.7, 3.7, 3.7, 4, 3.9, 3.8, 3.7, 4.1, 4.2, 4.2, 4.1, 3.9, 4, 4, 4.8, 4.7, 4.6, 4.2, 3.5, 4.6, 3.8, 4.3, 4.6, 4, 4, 4.7, 4, 3.9, 3.7, 4.1, 4.2, 3.9, 3.9, 4.2, 3.8, 3.7, 4.3, 4.1, 3.9, 4.3, 3.4, 4, 3.7, 4.5, 4.6, 4.3, 3.7, 3.9, 4.2, 4.5, 4.5, 4.2, 4.3, 4.2, 4.6, 3.4, 4.1, 4.4, 4.6, 4, 4.2, 4.3, 3.3, 4.2, 3.9, 3.7, 2.8, 4.5, 4.4, 4.2, 4.6, 4.1, 4.2, 3.8, 3.2, 4.5, 4.1, 3.5, 3.2, 4.5, 4, 4.2, 4.3, 4.4, 3, 4.1, 4.2, 3.7, 4.3, 4.3, 4.3, 3.9, 4.3, 4.4, 4.1, 3.6, 4.3, 4.7, 4.6, 4.1, 4, 3.4, 3.8, 4.8, 3.5, 3.9, 3.5, 4, 4.1, 3.8, 4, 3.9, 4.7, 4.2, 4, 3.9, 3.8, 3.5, 2.6, 4.4, 4.1, 4.2, 4, 3.8, 4.2, 3.7, 3.5, 3.9, 4.1, 4.4, 3.4, 3.8, 4.2, 3.9, 4.7, 4.2, 4, 3.7, 4.2, 3.6, 3.8, 4.7, 3.8, 3.6, 3.7, 3.4, 4, 4.4, 4, 4.6, 4.9, 4, 4, 4.2, 3.9, 3.8, 4.7, 3.8, 4.1, 4.5, 3.6, 3.7, 3.8, 3.7, 4.6, 4.4, 4.2, 4.5, 3.7, 4.7, 3.2, 3.9, 4, 4.1, 3.7, 3.6, 3.1, 3.8, 2.3, 3.6, 3.4, 4.3, 4, 4.4, 4.5, 4.1, 4.1, 4, 4.7, 3.9, 4.3, 4.2, 4.2, 3.6, 4.3, 4.3, 4.1, 3.9, 4.5, 3.8, 3.9, 4.3, 3.8, 4.5, 4.7, 3.6, 4.4, 3.8, 3.7, 4, 3.5, 3.2, 3.8, 4.1, 4, 4.1, 3.7, 3.9, 3.2, 4.3, 4.2, 4, 4.3, 4.2, 4.3, 4.1, 4.6, 4.2, 3.8, 4.5, 3.6, 3.7, 4.1, 4, 4.3, 3.8, 4.1, 3.9, 2.9, 4.2, 3.5, 4.4, 4, 3.3
plt.ylabel('Count', fontsize= 18)
plt.xlim((1,5))
plt.show()

# %%
plt.scatter(coffee.price_level, coffee.rating, lw=0, alpha=.1)
plt.show()

# %%
max(coffee.price_level)
coffee_review_plot = coffee_reviews[pd.notnull(coffee_reviews['rating'])]

# %%
plt.show()

# %%
coffee_review_plot[['rating_count','rating_score']].head()
# Out:
#    rating_count  rating_score
# 0             5           3.0
# 3             5           4.0
# 6             5           4.2
# 8             5           4.2
# 9             5           4.6
#
# [5 rows x 2 columns]

# %%
coffee_reviews
# Out:
#     rating                                    name  \
# 0      3.6                            Tatiana Cafe
# 1      NaN                          Dunkin' Donuts
# 2      NaN                  Trigo Cafe Corporation
# 3      3.7                         Footprints Cafe
# 4      NaN                            Third Season
# 5      NaN                               inLifeNYC
# 6      3.9                         Ocean View Cafe
# 7      NaN                           La Petit Cafe
# 8      4.2                               Starbucks
# 9      3.9                            Kashkar Cafe
# 10     3.9                             Anyway Cafe
# 11     NaN                               Cafeteria
# 12     NaN                          Dunkin' Donuts
# 13     3.9                            Cafe Glechik
# 14     NaN                              Cafe Paris
# 15     NaN                         Cafe Dolce Vita
# 16     NaN                        Panini Tozt Cafe
# ...

# %%
import matplotlib.pyplot as plt
fig, axes = plt.subplots(nrows=1, ncols=5, figsize=(15, 8), tight_layout=True)

font = {'size'   : 14}
tmp_len = []
for ax, num in zip(axes.ravel(), range(1,6)):
    if num<6:
        tmp = coffee_reviews[coffee_reviews['rating_count'] == num].rating_score
        tmp_len.append(len(tmp))
    else:
        tmp = coffee_reviews[coffee_reviews['rating_count'] == num-5] 
        tmp = tmp[tmp['rating_score'] != 5.0].rating_score
        
#     if num == 1:
#         b = np.arange(1,6,1)
#     elif num ==2:
    b = np.arange(1,5+1.0/2.0,1.0/2.0)
#     elif num ==3:
#         b = np.arange(1,5+1.0/3.0,1.0/3.0)
#     elif num ==4:
#         b = np.arange(1,5+1.0/4.0,1.0/4.0)
#     elif num ==5:
#         b = np.arange(1,5+1.0/5.0,1.0/5.0)       
     #histogram of all the movies by year -- normed, so max is highest level, 0 is lowest level -- in red
   
    width = 0.5
    if num==1:
        width = 1
    ax.hist(is_series, bins = b, histtype='stepfilled', normed=1, color='#cccccc', alpha=1)
    tmp.hist(ax = ax,bins = b, histtype='stepfilled', normed=1, color='r', alpha=0.4)
    ax.set_ylim([0, 1])
    ax.set_xlabel('Score',fontsize=14)
    title_str = '%d reviewer(s)' %(num)
    if num == 5:
           title_str = '%d+ reviewer(s)' %(num)
    ax.set_title(title_str,fontsize=18)
    ax.xaxis.set_ticklabels(['1', '', '2', '', '3', '', '4', '', '5'])
    for label in ax.xaxis.get_ticklabels():
        # label is a Text instance
        label.set_fontsize(14) 
        
    for label in ax.yaxis.get_ticklabels():
        # label is a Text instance
        label.set_fontsize(14) 
# for tick in ax.xaxis.get_major_ticks():
#                 tick.label.set_fontsize(14)
    #ax.hist(tmp, histtype='stepfilled', normed=True, color='r', alpha=.2, ec='none')
    
    # Histogram of movies per year for all movies -- serves as the identical background for the graph.

# %%
plt.show()

# %% [markdown]
# tmp

# %%
(tmp_len)
# Out:
# [247, 217, 204, 149, 1245]

# %%
len(coffee_reviews)
# Out:
# 2601
